# %%
import pyreadr
import scanpy as sc
import numpy as np
import os
import pandas as pd
import anndata as ad
from pathlib import Path

# %% [markdown]
# * Load datasets

# %%
# load datasets
adata_multiome_raw = sc.read_h5ad(
    "/data/BCI-CRC/SO/data/CRC_multiome/scanpy/CRCLM_finalAnalysis/CRCLM_decon_scvi_RAW.h5ad"
)
adata_multiome_annot = sc.read_h5ad(
    "/data/BCI-CRC/nasrine/data/CRC/multiome/CRC_LM_01_15/final_object/CRC_LM_decon_scvi_final_annotations.h5ad"
)
adata_multiome_raw.var_names_make_unique()

adata_che2021 = sc.read_10x_mtx("/data/BCI-CRC/SO/data/public/Che2021_CRC-LM_scRNAseq/")
adata_che2021.var_names_make_unique()

adata_wu2022 = sc.read_h5ad(
    "/data/BCI-CRC/nasrine/data/CRC/Wu_Yingcheng_2021_cancer_discovery/Wu2021_counts.h5ad"
)
adata_wu2022.var_names_make_unique()

# %% [markdown]
# #### For multiome
# * select only annotated cells from final object
# * get raw counts for them
# * append annotations

# %%
adata_multiome_raw
# Out:
# AnnData object with n_obs × n_vars = 23119 × 36485
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Patient', 'Therapy', 'Tissue', 'TSSEnrichment', 'nFrags', 'percent.mt', 'percent.ribo', 'RNA_snn_res.0.5', 'seurat_clusters', 'integrated_snn_res.0.5', 'Clusters_all_cells_preDecon', 'Cell_type_preDecon', 'ident', 'decontX_contamination', 'decontX_clusters', 'integratedRNADecon_snn_res.0.5', 'X_scvi_batch', 'X_scvi_labels', 'leiden', 'Cell_type', 'nCount_Peaks', 'nFeature_Peaks', 'nCount_ATAC', 'nFeature_ATAC', 'nCount_integratedRNADecon', 'nFeature_integratedRNADecon', 'RNA.weight', 'ATAC.weight', 'wsnn_res.0.5'
#     obsm: 'X_ATAC', 'X_UMAP', 'X_WNN'

# %%
# replace annotation convention
adata_multiome_raw.obs["Cell_type"] = np.where(
    adata_multiome_raw.obs["Cell_type"] == "T/NK/ILC",
    "T-NK-ILC",
    adata_multiome_raw.obs["Cell_type"],
)

# %%
adata_multiome_raw.obs["Cell_type"]
# Out:
# CRC01_LM#AAACATGCATCAGCAC-1       Myeloid
# CRC01_LM#AACATAGCACTATGGC-1    Epithelial
# CRC01_LM#AACATAGCAGGATAAC-1       Myeloid
# CRC01_LM#AACCTCCTCCAGCACA-1    Epithelial
# CRC01_LM#AACGCCCAGCTGGAAA-1    Epithelial
#                                   ...
# CRC15_LM#TTTGTCCCAGGAATCG-1    Epithelial
# CRC15_LM#TTTGTCTAGGTCCACA-1      T-NK-ILC
# CRC15_LM#TTTGTGAAGCATGAAG-1      T-NK-ILC
# CRC15_LM#TTTGTGAAGGACTTAC-1    Epithelial
# CRC15_LM#TTTGTGAAGGAGCATA-1      T-NK-ILC
# Name: Cell_type, Length: 23119, dtype: object

# %%
set(adata_multiome_raw.obs.Tissue)
# Out:
# {'LM'}

# %%
# for now for the muliome no annotation
adata_multiome_raw.obs["Cell_subtype"] = "No annotation"

# %%
adata_multiome_raw.obs
# Out:
#                                 orig.ident  nCount_RNA  nFeature_RNA  \
# CRC01_LM#AAACATGCATCAGCAC-1  SeuratProject         981           727
# CRC01_LM#AACATAGCACTATGGC-1  SeuratProject        1957          1239
# CRC01_LM#AACATAGCAGGATAAC-1  SeuratProject         461           365
# CRC01_LM#AACCTCCTCCAGCACA-1  SeuratProject        8024          4208
# CRC01_LM#AACGCCCAGCTGGAAA-1  SeuratProject       15306          6289
# ...                                    ...         ...           ...
# CRC15_LM#TTTGTCCCAGGAATCG-1  SeuratProject        4131          2402
# CRC15_LM#TTTGTCTAGGTCCACA-1  SeuratProject        1110           806
# CRC15_LM#TTTGTGAAGCATGAAG-1  SeuratProject        1142           810
# CRC15_LM#TTTGTGAAGGACTTAC-1  SeuratProject        3550          2256
# CRC15_LM#TTTGTGAAGGAGCATA-1  SeuratProject        1162           837
#
#                                Sample Patient Therapy Tissue  TSSEnrichment  \
# CRC01_LM#AAACATGCATCAGCAC-1  CRC01_LM   CRC01     NAC     LM          9.078
# CRC01_LM#AACATAGCACTATGGC-1  CRC01_LM   CRC01     NAC     LM          7.485
# CRC01_LM#AACATAGCAGGATAAC-1  CRC01_LM   CRC01     NAC     LM          6.041
# CRC01_LM#AACCTCCTCCAGCACA-1  CRC01_LM   CRC01     NAC     LM          9.830
# CRC01_LM#AACGCCCAGCTGGAAA-1  CRC01_LM   CRC01     NAC     LM          6.133
# ...                               ...     ...     ...    ...            ...
# CRC15_LM#TTTGTCCCAGGAATCG-1  CRC15_LM   CRC15     NAC     LM          6.215
# CRC15_LM#TTTGTCTAGGTCCACA-1  CRC15_LM   CRC15     NAC     LM         10.594
# CRC15_LM#TTTGTGAAGCATGAAG-1  CRC15_LM   CRC15     NAC     LM          5.428
# CRC15_LM#TTTGTGAAGGACTTAC-1  CRC15_LM   CRC15     NAC     LM          4.999
# CRC15_LM#TTTGTGAAGGAGCATA-1  CRC15_LM   CRC15     NAC     LM          9.260
#
#                              nFrags  percent.mt  ...  nCount_Peaks  \
# CRC01_LM#AAACATGCATCAGCAC-1    1890    3.771662  ...           454
# CRC01_LM#AACATAGCACTATGGC-1    2784    9.197752  ...          1040
# CRC01_LM#AACATAGCAGGATAAC-1    1923    1.301518  ...           442
# CRC01_LM#AACCTCCTCCAGCACA-1    3301    2.243270  ...          1654
# CRC01_LM#AACGCCCAGCTGGAAA-1   19026    3.397361  ...          4962
# ...                             ...         ...  ...           ...
# CRC15_LM#TTTGTCCCAGGAATCG-1    5786    4.671992  ...          1173
# CRC15_LM#TTTGTCTAGGTCCACA-1    1538    4.414414  ...           355
# CRC15_LM#TTTGTGAAGCATGAAG-1    9636    8.406305  ...          1322
# CRC15_LM#TTTGTGAAGGACTTAC-1    7830    0.309859  ...          1677
# CRC15_LM#TTTGTGAAGGAGCATA-1    2014    3.442341  ...           749
#
#                              nFeature_Peaks  nCount_ATAC  nFeature_ATAC  \
# CRC01_LM#AAACATGCATCAGCAC-1             450          305            162
# CRC01_LM#AACATAGCACTATGGC-1            1023          724            376
# CRC01_LM#AACATAGCAGGATAAC-1             441          251            133
# CRC01_LM#AACCTCCTCCAGCACA-1            1620         1000            531
# CRC01_LM#AACGCCCAGCTGGAAA-1            4657         3476           1712
# ...                                     ...          ...            ...
# CRC15_LM#TTTGTCCCAGGAATCG-1            1144          954            513
# CRC15_LM#TTTGTCTAGGTCCACA-1             352          356            192
# CRC15_LM#TTTGTGAAGCATGAAG-1            1280         1155            589
# CRC15_LM#TTTGTGAAGGACTTAC-1            1645         1269            680
# CRC15_LM#TTTGTGAAGGAGCATA-1             723          796            413
#
#                              nCount_integratedRNADecon  \
# CRC01_LM#AAACATGCATCAGCAC-1                 926.971718
# CRC01_LM#AACATAGCACTATGGC-1                1675.916173
# CRC01_LM#AACATAGCAGGATAAC-1                 432.982580
# CRC01_LM#AACCTCCTCCAGCACA-1                7597.421457
# CRC01_LM#AACGCCCAGCTGGAAA-1               13876.588890
# ...                                                ...
# CRC15_LM#TTTGTCCCAGGAATCG-1                3072.652178
# CRC15_LM#TTTGTCTAGGTCCACA-1                 974.865972
# CRC15_LM#TTTGTGAAGCATGAAG-1                 981.736507
# CRC15_LM#TTTGTGAAGGACTTAC-1                3377.198380
# CRC15_LM#TTTGTGAAGGAGCATA-1                 999.190840
#
#                             nFeature_integratedRNADecon RNA.weight  \
# CRC01_LM#AAACATGCATCAGCAC-1                         704   0.296429
# CRC01_LM#AACATAGCACTATGGC-1                        1213   0.471572
# CRC01_LM#AACATAGCAGGATAAC-1                         344   0.512933
# CRC01_LM#AACCTCCTCCAGCACA-1                        4131   0.748984
# CRC01_LM#AACGCCCAGCTGGAAA-1                        6189   0.399255
# ...                                                 ...        ...
# CRC15_LM#TTTGTCCCAGGAATCG-1                        2316   0.857876
# CRC15_LM#TTTGTCTAGGTCCACA-1                         766   0.204801
# CRC15_LM#TTTGTGAAGCATGAAG-1                         776   0.503726
# CRC15_LM#TTTGTGAAGGACTTAC-1                        2188   0.520234
# CRC15_LM#TTTGTGAAGGAGCATA-1                         792   0.928626
#
#                              ATAC.weight wsnn_res.0.5   Cell_subtype
# CRC01_LM#AAACATGCATCAGCAC-1     0.703571            3  No annotation
# CRC01_LM#AACATAGCACTATGGC-1     0.528428           16  No annotation
# CRC01_LM#AACATAGCAGGATAAC-1     0.487067            3  No annotation
# CRC01_LM#AACCTCCTCCAGCACA-1     0.251016           16  No annotation
# CRC01_LM#AACGCCCAGCTGGAAA-1     0.600745           16  No annotation
# ...                                  ...          ...            ...
# CRC15_LM#TTTGTCCCAGGAATCG-1     0.142124           11  No annotation
# CRC15_LM#TTTGTCTAGGTCCACA-1     0.795199           15  No annotation
# CRC15_LM#TTTGTGAAGCATGAAG-1     0.496274            6  No annotation
# CRC15_LM#TTTGTGAAGGACTTAC-1     0.479766            5  No annotation
# CRC15_LM#TTTGTGAAGGAGCATA-1     0.071374            6  No annotation
#
# [23119 rows x 34 columns]

# %%
adata_multiome_raw.obs.Cell_type.value_counts()
# Out:
# Epithelial     17774
# Myeloid         1936
# T-NK-ILC        1604
# Stromal          675
# Endothelial      494
# Hepatocyte       474
# B                162
# Name: Cell_type, dtype: int64

# %%
adata_multiome_raw[adata_multiome_raw.obs["Cell_type"] != "Epithelial"].copy()
# Out:
# AnnData object with n_obs × n_vars = 5345 × 36485
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Patient', 'Therapy', 'Tissue', 'TSSEnrichment', 'nFrags', 'percent.mt', 'percent.ribo', 'RNA_snn_res.0.5', 'seurat_clusters', 'integrated_snn_res.0.5', 'Clusters_all_cells_preDecon', 'Cell_type_preDecon', 'ident', 'decontX_contamination', 'decontX_clusters', 'integratedRNADecon_snn_res.0.5', 'X_scvi_batch', 'X_scvi_labels', 'leiden', 'Cell_type', 'nCount_Peaks', 'nFeature_Peaks', 'nCount_ATAC', 'nFeature_ATAC', 'nCount_integratedRNADecon', 'nFeature_integratedRNADecon', 'RNA.weight', 'ATAC.weight', 'wsnn_res.0.5', 'Cell_subtype'
#     obsm: 'X_ATAC', 'X_UMAP', 'X_WNN'

# %%
adata_multiome_raw[
    adata_multiome_raw.obs["Cell_type"] != "Epithelial"
].obs.Cell_type.value_counts()
# Out:
# Myeloid        1936
# T-NK-ILC       1604
# Stromal         675
# Endothelial     494
# Hepatocyte      474
# B               162
# Name: Cell_type, dtype: int64

# %%
# remove epithelial cells from multiome because Sam is annotating them
adata_multiome_raw_liver = adata_multiome_raw[
    adata_multiome_raw.obs["Cell_type"] != "Epithelial"
].copy()

# %%
adata_multiome_raw_liver.obs.Cell_type.value_counts()
# Out:
# Myeloid        1936
# T-NK-ILC       1604
# Stromal         675
# Endothelial     494
# Hepatocyte      474
# B               162
# Name: Cell_type, dtype: int64

# %% [markdown]
# #### create metadata for che2021 dataset

# %%
adata_che2021.obs["Patient"] = [
    ele[1] for ele in adata_che2021.obs.index.str.split("_")
]
adata_che2021.obs["Tissue"] = [ele[2] for ele in adata_che2021.obs.index.str.split("_")]
adata_che2021.obs["Therapy"] = np.where(
    (
        (adata_che2021.obs["Patient"] == "COL15")
        | (adata_che2021.obs["Patient"] == "COL17")
        | (adata_che2021.obs["Patient"] == "COL18")
    ),
    "NAC",  # neoadjuvant chemotherapy, preoperative chemotherapy
    "naive",
)

# %%
# load annotations from previous analysis
# read in annotations
gen_annot = pd.read_csv(
    "/data/BCI-CRC/nasrine/data/CRC/Che2021_CRC-LM_scRNAseq/Che2021_CRC_LM_clustering_annotations.txt",
    header=0,
    index_col=0,
    sep="\t",
)
gen_annot.rename(columns={"Annotation": "Cell_type"}, inplace=True)

# merge to add annot to .obs
adata_che2021.obs = adata_che2021.obs.merge(
    right=gen_annot, how="left", right_index=True, left_index=True
)

tcell_annot_che2021 = pd.read_csv(
    "/data/BCI-CRC/nasrine/data/CRC/Che2021_CRC-LM_scRNAseq/Che2021_CRC_LM_TNKILC_clustering_annotations.txt",
    header=0,
    index_col=0,
    sep="\t",
)

cDC1_migDC_annot_che2021 = pd.read_csv(
    "/data/BCI-CRC/nasrine/data/CRC/Che2021_CRC-LM_scRNAseq/Che2021_CRC_LM_cDC1_migDC_annotations.txt",
    header=0,
    index_col=0,
    sep="\t",
)

myeloid_annot_che2021 = pd.read_csv(
    "/data/BCI-CRC/nasrine/data/CRC/Che2021_CRC-LM_scRNAseq/Che2021_CRC_LM_myeloid_clustering_annotations.txt",
    header=0,
    index_col=0,
    sep="\t",
)

stromal_annot_che2021 = pd.read_csv(
    "/data/BCI-CRC/nasrine/data/CRC/Che2021_CRC-LM_scRNAseq/Che2021_CRC_LM_stromal_clustering_annotations.txt",
    header=0,
    index_col=0,
    sep="\t",
)

complete_annot_che2021 = pd.concat(
    [
        tcell_annot_che2021,
        cDC1_migDC_annot_che2021,
        myeloid_annot_che2021,
        stromal_annot_che2021,
    ],
    axis=0,
)
complete_annot_che2021.rename(columns={"Annotation": "Cell_subtype"}, inplace=True)

# add annot to .obs
adata_che2021.obs = adata_che2021.obs.merge(
    right=complete_annot_che2021, how="left", right_index=True, left_index=True
)

adata_che2021.obs["Cell_subtype"] = np.where(
    adata_che2021.obs["Cell_subtype"].isna(),
    adata_che2021.obs["Cell_type"],
    adata_che2021.obs["Cell_subtype"],
)

# %%
adata_che2021.obs
# Out:
#                             Patient Tissue Therapy   Cell_type Cell_subtype
# AAACCTGAGAAACCTA_COL07_CRC    COL07    CRC   naive  Epithelial   Epithelial
# AAACCTGAGACAATAC_COL07_CRC    COL07    CRC   naive     Myeloid         cDC2
# AAACCTGAGACGCAAC_COL07_CRC    COL07    CRC   naive           B            B
# AAACCTGAGCAGATCG_COL07_CRC    COL07    CRC   naive    T/NK/ILC         Treg
# AAACCTGAGCTATGCT_COL07_CRC    COL07    CRC   naive         NaN          NaN
# ...                             ...    ...     ...         ...          ...
# TTTGTCAGTTGGGACA_COL18_PBMC   COL18   PBMC     NAC         NaN          NaN
# TTTGTCATCATGTGGT_COL18_PBMC   COL18   PBMC     NAC         NaN          NaN
# TTTGTCATCCGCATCT_COL18_PBMC   COL18   PBMC     NAC         NaN          NaN
# TTTGTCATCGGAATCT_COL18_PBMC   COL18   PBMC     NAC         NaN          NaN
# TTTGTCATCGGTTAAC_COL18_PBMC   COL18   PBMC     NAC         NaN          NaN
#
# [140281 rows x 5 columns]

# %% [markdown]
# ### Isolate metastatic CRC LM samples only
#
# * multiome is done

# %%
set(adata_multiome_raw_liver.obs.Tissue)
# Out:
# {'LM'}

# %% [markdown]
# * Che2021

# %%
set(adata_che2021.obs.Tissue)
# Out:
# {'CRC', 'LM', 'PBMC'}

# %%
adata_che2021_liver = adata_che2021[adata_che2021.obs.Tissue == "LM"].copy()
print(adata_che2021_liver.shape)
print(set(adata_che2021_liver.obs.Tissue))
# Out:
# (57596, 33694)
# {'LM'}

# %%
adata_che2021_liver.obs
# Out:
#                           Patient Tissue Therapy   Cell_type  \
# AAACCTGAGACTAGGC_COL07_LM   COL07     LM   naive  Epithelial
# AAACCTGAGAGTACAT_COL07_LM   COL07     LM   naive  cDC1/migDC
# AAACCTGAGAGTGACC_COL07_LM   COL07     LM   naive         pDC
# AAACCTGAGGATCGCA_COL07_LM   COL07     LM   naive  Epithelial
# AAACCTGAGGCTAGAC_COL07_LM   COL07     LM   naive    T/NK/ILC
# ...                           ...    ...     ...         ...
# TTTGTCATCGGTCTAA_COL18_LM   COL18     LM     NAC           B
# TTTGTCATCTCGCATC_COL18_LM   COL18     LM     NAC     Myeloid
# TTTGTCATCTCGGACG_COL18_LM   COL18     LM     NAC    T/NK/ILC
# TTTGTCATCTGTGCAA_COL18_LM   COL18     LM     NAC    T/NK/ILC
# TTTGTCATCTTGCATT_COL18_LM   COL18     LM     NAC    T/NK/ILC
#
#                                 Cell_subtype
# AAACCTGAGACTAGGC_COL07_LM         Epithelial
# AAACCTGAGAGTACAT_COL07_LM               cDC1
# AAACCTGAGAGTGACC_COL07_LM                pDC
# AAACCTGAGGATCGCA_COL07_LM         Epithelial
# AAACCTGAGGCTAGAC_COL07_LM            MKI67 T
# ...                                      ...
# TTTGTCATCGGTCTAA_COL18_LM                  B
# TTTGTCATCTCGCATC_COL18_LM  Myeloid/T doublet
# TTTGTCATCTCGGACG_COL18_LM                NK2
# TTTGTCATCTGTGCAA_COL18_LM        Naive CD4 T
# TTTGTCATCTTGCATT_COL18_LM        Naive CD4 T
#
# [57596 rows x 5 columns]

# %%
adata_che2021_liver.obs.Cell_type.value_counts()
# Out:
# T/NK/ILC       39186
# Myeloid         8285
# Epithelial      3377
# Plasma           826
# B                788
# Stromal          432
# pDC              216
# cDC1/migDC       178
# Mast              91
# Endothelial       89
# Name: Cell_type, dtype: int64

# %%
# remove epithelial cells from Che2021 as sam is not analysing them
adata_che2021_liver = adata_che2021_liver[
    adata_che2021_liver.obs.Cell_type != "Epithelial"
].copy()

# %% [markdown]
# * Wu2022

# %%
set(adata_wu2022.obs.Tissue)
# Out:
# {'CRC', 'Colon_P', 'LM', 'LN', 'Liver_P', 'PBMC'}

# %%
adata_wu2022_liver = adata_wu2022[adata_wu2022.obs.Tissue == "LM"].copy()
print(adata_wu2022_liver.shape)
print(set(adata_wu2022_liver.obs.Tissue))
# Out:
# (55245, 20610)
# {'LM'}

# %%
adata_wu2022_liver.obs.main_cell_type.value_counts()
# Out:
# CD8        17168
# CD4        13873
# Myeloid     6523
# MAIT        4845
# NK          4626
# NEU         3319
# Treg        2779
# B           1346
# Plasma       766
# Name: main_cell_type, dtype: int64

# %% [markdown]
# * check that they are raw

# %%
np.max(adata_multiome_raw_liver.X)
# Out:
# 11459.0

# %%
np.max(adata_che2021_liver.X)
# Out:
# 23832.0

# %%
np.max(adata_wu2022_liver.X)
# Out:
# 40676.0

# %% [markdown]
# ### add  columns of interest and rename some so that it is all consistent in the workflow
# * Sample
# * Patient
# * Tissue
# * Therapy
# * Cell_type
# * Cell_subtype

# %%
adata_multiome_raw_liver.obs
# Out:
#                                 orig.ident  nCount_RNA  nFeature_RNA  \
# CRC01_LM#AAACATGCATCAGCAC-1  SeuratProject         981           727
# CRC01_LM#AACATAGCAGGATAAC-1  SeuratProject         461           365
# CRC01_LM#AACTCACAGAATGACG-1  SeuratProject        1710          1363
# CRC01_LM#AGAACAAGTGGTTATG-1  SeuratProject        1220           983
# CRC01_LM#AGGTTGCGTGAGCAAG-1  SeuratProject       10885          5086
# ...                                    ...         ...           ...
# CRC15_LM#TTTCCGGGTAGGTTGC-1  SeuratProject         982           709
# CRC15_LM#TTTGCGGAGTGAACAG-1  SeuratProject        1033           747
# CRC15_LM#TTTGTCTAGGTCCACA-1  SeuratProject        1110           806
# CRC15_LM#TTTGTGAAGCATGAAG-1  SeuratProject        1142           810
# CRC15_LM#TTTGTGAAGGAGCATA-1  SeuratProject        1162           837
#
#                                Sample Patient Therapy Tissue  TSSEnrichment  \
# CRC01_LM#AAACATGCATCAGCAC-1  CRC01_LM   CRC01     NAC     LM          9.078
# CRC01_LM#AACATAGCAGGATAAC-1  CRC01_LM   CRC01     NAC     LM          6.041
# CRC01_LM#AACTCACAGAATGACG-1  CRC01_LM   CRC01     NAC     LM         15.662
# CRC01_LM#AGAACAAGTGGTTATG-1  CRC01_LM   CRC01     NAC     LM          5.246
# CRC01_LM#AGGTTGCGTGAGCAAG-1  CRC01_LM   CRC01     NAC     LM          7.196
# ...                               ...     ...     ...    ...            ...
# CRC15_LM#TTTCCGGGTAGGTTGC-1  CRC15_LM   CRC15     NAC     LM          8.245
# CRC15_LM#TTTGCGGAGTGAACAG-1  CRC15_LM   CRC15     NAC     LM         11.347
# CRC15_LM#TTTGTCTAGGTCCACA-1  CRC15_LM   CRC15     NAC     LM         10.594
# CRC15_LM#TTTGTGAAGCATGAAG-1  CRC15_LM   CRC15     NAC     LM          5.428
# CRC15_LM#TTTGTGAAGGAGCATA-1  CRC15_LM   CRC15     NAC     LM          9.260
#
#                              nFrags  percent.mt  ...  nCount_Peaks  \
# CRC01_LM#AAACATGCATCAGCAC-1    1890    3.771662  ...           454
# CRC01_LM#AACATAGCAGGATAAC-1    1923    1.301518  ...           442
# CRC01_LM#AACTCACAGAATGACG-1    1683    2.456140  ...           460
# CRC01_LM#AGAACAAGTGGTTATG-1   10832    2.377049  ...          1760
# CRC01_LM#AGGTTGCGTGAGCAAG-1    8739    2.351860  ...          2909
# ...                             ...         ...  ...           ...
# CRC15_LM#TTTCCGGGTAGGTTGC-1    1543    3.767821  ...           277
# CRC15_LM#TTTGCGGAGTGAACAG-1    2734    4.549855  ...           964
# CRC15_LM#TTTGTCTAGGTCCACA-1    1538    4.414414  ...           355
# CRC15_LM#TTTGTGAAGCATGAAG-1    9636    8.406305  ...          1322
# CRC15_LM#TTTGTGAAGGAGCATA-1    2014    3.442341  ...           749
#
#                              nFeature_Peaks  nCount_ATAC  nFeature_ATAC  \
# CRC01_LM#AAACATGCATCAGCAC-1             450          305            162
# CRC01_LM#AACATAGCAGGATAAC-1             441          251            133
# CRC01_LM#AACTCACAGAATGACG-1             456          387            195
# CRC01_LM#AGAACAAGTGGTTATG-1            1713         1102            573
# CRC01_LM#AGGTTGCGTGAGCAAG-1            2801         1966           1019
# ...                                     ...          ...            ...
# CRC15_LM#TTTCCGGGTAGGTTGC-1             273          291            154
# CRC15_LM#TTTGCGGAGTGAACAG-1             930         1125            560
# CRC15_LM#TTTGTCTAGGTCCACA-1             352          356            192
# CRC15_LM#TTTGTGAAGCATGAAG-1            1280         1155            589
# CRC15_LM#TTTGTGAAGGAGCATA-1             723          796            413
#
#                              nCount_integratedRNADecon  \
# CRC01_LM#AAACATGCATCAGCAC-1                 926.971718
# CRC01_LM#AACATAGCAGGATAAC-1                 432.982580
# CRC01_LM#AACTCACAGAATGACG-1                1552.642975
# CRC01_LM#AGAACAAGTGGTTATG-1                1170.950610
# CRC01_LM#AGGTTGCGTGAGCAAG-1               10480.888601
# ...                                                ...
# CRC15_LM#TTTCCGGGTAGGTTGC-1                 911.653883
# CRC15_LM#TTTGCGGAGTGAACAG-1                 943.988647
# CRC15_LM#TTTGTCTAGGTCCACA-1                 974.865972
# CRC15_LM#TTTGTGAAGCATGAAG-1                 981.736507
# CRC15_LM#TTTGTGAAGGAGCATA-1                 999.190840
#
#                             nFeature_integratedRNADecon RNA.weight  \
# CRC01_LM#AAACATGCATCAGCAC-1                         704   0.296429
# CRC01_LM#AACATAGCAGGATAAC-1                         344   0.512933
# CRC01_LM#AACTCACAGAATGACG-1                        1301   0.382379
# CRC01_LM#AGAACAAGTGGTTATG-1                         957   0.465358
# CRC01_LM#AGGTTGCGTGAGCAAG-1                        5010   0.977986
# ...                                                 ...        ...
# CRC15_LM#TTTCCGGGTAGGTTGC-1                         680   0.168251
# CRC15_LM#TTTGCGGAGTGAACAG-1                         714   0.821833
# CRC15_LM#TTTGTCTAGGTCCACA-1                         766   0.204801
# CRC15_LM#TTTGTGAAGCATGAAG-1                         776   0.503726
# CRC15_LM#TTTGTGAAGGAGCATA-1                         792   0.928626
#
#                              ATAC.weight wsnn_res.0.5   Cell_subtype
# CRC01_LM#AAACATGCATCAGCAC-1     0.703571            3  No annotation
# CRC01_LM#AACATAGCAGGATAAC-1     0.487067            3  No annotation
# CRC01_LM#AACTCACAGAATGACG-1     0.617621            3  No annotation
# CRC01_LM#AGAACAAGTGGTTATG-1     0.534642           18  No annotation
# CRC01_LM#AGGTTGCGTGAGCAAG-1     0.022014           14  No annotation
# ...                                  ...          ...            ...
# CRC15_LM#TTTCCGGGTAGGTTGC-1     0.831749           15  No annotation
# CRC15_LM#TTTGCGGAGTGAACAG-1     0.178167            6  No annotation
# CRC15_LM#TTTGTCTAGGTCCACA-1     0.795199           15  No annotation
# CRC15_LM#TTTGTGAAGCATGAAG-1     0.496274            6  No annotation
# CRC15_LM#TTTGTGAAGGAGCATA-1     0.071374            6  No annotation
#
# [5345 rows x 34 columns]

# %%
adata_che2021_liver.obs
# Out:
#                           Patient Tissue Therapy   Cell_type  \
# AAACCTGAGAGTACAT_COL07_LM   COL07     LM   naive  cDC1/migDC
# AAACCTGAGAGTGACC_COL07_LM   COL07     LM   naive         pDC
# AAACCTGAGGCTAGAC_COL07_LM   COL07     LM   naive    T/NK/ILC
# AAACCTGAGTGCCAGA_COL07_LM   COL07     LM   naive     Myeloid
# AAACCTGAGTGGTAGC_COL07_LM   COL07     LM   naive    T/NK/ILC
# ...                           ...    ...     ...         ...
# TTTGTCATCGGTCTAA_COL18_LM   COL18     LM     NAC           B
# TTTGTCATCTCGCATC_COL18_LM   COL18     LM     NAC     Myeloid
# TTTGTCATCTCGGACG_COL18_LM   COL18     LM     NAC    T/NK/ILC
# TTTGTCATCTGTGCAA_COL18_LM   COL18     LM     NAC    T/NK/ILC
# TTTGTCATCTTGCATT_COL18_LM   COL18     LM     NAC    T/NK/ILC
#
#                                 Cell_subtype
# AAACCTGAGAGTACAT_COL07_LM               cDC1
# AAACCTGAGAGTGACC_COL07_LM                pDC
# AAACCTGAGGCTAGAC_COL07_LM            MKI67 T
# AAACCTGAGTGCCAGA_COL07_LM           TAM SPP1
# AAACCTGAGTGGTAGC_COL07_LM        Naive CD4 T
# ...                                      ...
# TTTGTCATCGGTCTAA_COL18_LM                  B
# TTTGTCATCTCGCATC_COL18_LM  Myeloid/T doublet
# TTTGTCATCTCGGACG_COL18_LM                NK2
# TTTGTCATCTGTGCAA_COL18_LM        Naive CD4 T
# TTTGTCATCTTGCATT_COL18_LM        Naive CD4 T
#
# [54219 rows x 5 columns]

# %%
adata_wu2022_liver.obs
# Out:
#                                   orig.ident  nCount_RNA  nFeature_RNA  \
# barcode
# P11_Liver_T_TACCTGCTCAGCAATC     P11_Liver_T        2265           974
# P12_Liver_T_CATTGCCCATTCTCTA     P12_Liver_T        2919          1071
# P12_Liver_T_TCGAACAGTAACACGG     P12_Liver_T        2103           903
# P12_Liver_T_GTCAGCGAGGAGATAG     P12_Liver_T        1580           765
# P10_Liver_T2_GTTAGTGGTCGCATCG   P10_Liver_T2        3892          1368
# ...                                      ...         ...           ...
# P8_Liver_T_GAGAAATAGGCCTGAA       P8_Liver_T       17023          2624
# P15_Liver_T_TTATTGCTCGCTAATG-1   P15_Liver_T        3453           903
# P17_Liver_T_AAATGGACATGGAAGC-1   P17_Liver_T        7002          1680
# P18_Liver_T_TAACCAGCACTGCGAC-1   P18_Liver_T        2594           776
# P19_Liver_T_ATTTACCAGCGACTGA-1   P19_Liver_T        4740          1364
#
#                                patient    tissue patient_tissue tissueunique  \
# barcode
# P11_Liver_T_TACCTGCTCAGCAATC       P11   Liver_T    P11_Liver_T      Liver_T
# P12_Liver_T_CATTGCCCATTCTCTA       P12   Liver_T    P12_Liver_T      Liver_T
# P12_Liver_T_TCGAACAGTAACACGG       P12   Liver_T    P12_Liver_T      Liver_T
# P12_Liver_T_GTCAGCGAGGAGATAG       P12   Liver_T    P12_Liver_T      Liver_T
# P10_Liver_T2_GTTAGTGGTCGCATCG      P10  Liver_T2   P10_Liver_T2      Liver_T
# ...                                ...       ...            ...          ...
# P8_Liver_T_GAGAAATAGGCCTGAA         P8   Liver_T     P8_Liver_T      Liver_T
# P15_Liver_T_TTATTGCTCGCTAATG-1     P15   Liver_T    P15_Liver_T      Liver_T
# P17_Liver_T_AAATGGACATGGAAGC-1     P17   Liver_T    P17_Liver_T      Liver_T
# P18_Liver_T_TAACCAGCACTGCGAC-1     P18   Liver_T    P18_Liver_T      Liver_T
# P19_Liver_T_ATTTACCAGCGACTGA-1     P19   Liver_T    P19_Liver_T      Liver_T
#
#                                 RNA_snn_res.0.5  seurat_clusters  \
# barcode
# P11_Liver_T_TACCTGCTCAGCAATC                  1                1
# P12_Liver_T_CATTGCCCATTCTCTA                  1                1
# P12_Liver_T_TCGAACAGTAACACGG                  1                1
# P12_Liver_T_GTCAGCGAGGAGATAG                  1                1
# P10_Liver_T2_GTTAGTGGTCGCATCG                 2                2
# ...                                         ...              ...
# P8_Liver_T_GAGAAATAGGCCTGAA                   5                5
# P15_Liver_T_TTATTGCTCGCTAATG-1                5                5
# P17_Liver_T_AAATGGACATGGAAGC-1                5                5
# P18_Liver_T_TAACCAGCACTGCGAC-1                5                5
# P19_Liver_T_ATTTACCAGCGACTGA-1                5                5
#
#                                 RNA_snn_res.0.1  doublet  RNA_snn_res.1  \
# barcode
# P11_Liver_T_TACCTGCTCAGCAATC                  0  Singlet              3
# P12_Liver_T_CATTGCCCATTCTCTA                  0  Singlet              3
# P12_Liver_T_TCGAACAGTAACACGG                  0  Singlet              3
# P12_Liver_T_GTCAGCGAGGAGATAG                  0  Singlet              3
# P10_Liver_T2_GTTAGTGGTCGCATCG                 0  Singlet              4
# ...                                         ...      ...            ...
# P8_Liver_T_GAGAAATAGGCCTGAA                   3  Singlet             24
# P15_Liver_T_TTATTGCTCGCTAATG-1                3  Singlet             24
# P17_Liver_T_AAATGGACATGGAAGC-1                3  Singlet             24
# P18_Liver_T_TAACCAGCACTGCGAC-1                3  Singlet             24
# P19_Liver_T_ATTTACCAGCGACTGA-1                3  Singlet             24
#
#                                main_cell_type         sub_cell_type  \
# barcode
# P11_Liver_T_TACCTGCTCAGCAATC              CD4            CCR6+ Th17
# P12_Liver_T_CATTGCCCATTCTCTA              CD4            CCR6+ Th17
# P12_Liver_T_TCGAACAGTAACACGG              CD4    CCL5+ CD4+ T cells
# P12_Liver_T_GTCAGCGAGGAGATAG              CD8    GZMK+ CD8+ T cells
# P10_Liver_T2_GTTAGTGGTCGCATCG             CD4    CCL5+ CD4+ T cells
# ...                                       ...                   ...
# P8_Liver_T_GAGAAATAGGCCTGAA            Plasma  IGHG+ Plasma B cells
# P15_Liver_T_TTATTGCTCGCTAATG-1         Plasma  IGHA+ Plasma B cells
# P17_Liver_T_AAATGGACATGGAAGC-1         Plasma  IGHG+ Plasma B cells
# P18_Liver_T_TAACCAGCACTGCGAC-1         Plasma  IGHA+ Plasma B cells
# P19_Liver_T_ATTTACCAGCGACTGA-1         Plasma  IGHA+ Plasma B cells
#
#                                         chemo Therapy     Patient Tissue
# barcode
# P11_Liver_T_TACCTGCTCAGCAATC       pretreated   naive  Wu2021_P11     LM
# P12_Liver_T_CATTGCCCATTCTCTA       pretreated   naive  Wu2021_P12     LM
# P12_Liver_T_TCGAACAGTAACACGG       pretreated   naive  Wu2021_P12     LM
# P12_Liver_T_GTCAGCGAGGAGATAG       pretreated   naive  Wu2021_P12     LM
# P10_Liver_T2_GTTAGTGGTCGCATCG      pretreated   naive  Wu2021_P10     LM
# ...                                       ...     ...         ...    ...
# P8_Liver_T_GAGAAATAGGCCTGAA        pretreated   naive   Wu2021_P8     LM
# P15_Liver_T_TTATTGCTCGCTAATG-1  treated-PD/SD     NAC  Wu2021_P15     LM
# P17_Liver_T_AAATGGACATGGAAGC-1     pretreated   naive  Wu2021_P17     LM
# P18_Liver_T_TAACCAGCACTGCGAC-1  treated-PD/SD     NAC  Wu2021_P18     LM
# P19_Liver_T_ATTTACCAGCGACTGA-1  treated-PD/SD     NAC  Wu2021_P19     LM
#
# [55245 rows x 18 columns]

# %%
# change column names for wu2022
adata_wu2022_liver.obs.rename(columns={"main_cell_type": "Cell_type"}, inplace=True)
adata_wu2022_liver.obs.rename(columns={"sub_cell_type": "Cell_subtype"}, inplace=True)
# create sample column
adata_wu2022_liver.obs.rename(columns={"orig.ident": "Sample"}, inplace=True)

# create sample column for che2021
adata_che2021_liver.obs["Sample"] = (
    adata_che2021_liver.obs["Patient"].astype("str")
    + "_"
    + adata_che2021_liver.obs["Tissue"].astype("str")
)

# %%
adata_multiome_raw_liver
# Out:
# AnnData object with n_obs × n_vars = 5345 × 36485
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Sample', 'Patient', 'Therapy', 'Tissue', 'TSSEnrichment', 'nFrags', 'percent.mt', 'percent.ribo', 'RNA_snn_res.0.5', 'seurat_clusters', 'integrated_snn_res.0.5', 'Clusters_all_cells_preDecon', 'Cell_type_preDecon', 'ident', 'decontX_contamination', 'decontX_clusters', 'integratedRNADecon_snn_res.0.5', 'X_scvi_batch', 'X_scvi_labels', 'leiden', 'Cell_type', 'nCount_Peaks', 'nFeature_Peaks', 'nCount_ATAC', 'nFeature_ATAC', 'nCount_integratedRNADecon', 'nFeature_integratedRNADecon', 'RNA.weight', 'ATAC.weight', 'wsnn_res.0.5', 'Cell_subtype'
#     obsm: 'X_ATAC', 'X_UMAP', 'X_WNN'

# %%
adata_wu2022_liver
# Out:
# AnnData object with n_obs × n_vars = 55245 × 20610
#     obs: 'Sample', 'nCount_RNA', 'nFeature_RNA', 'patient', 'tissue', 'patient_tissue', 'tissueunique', 'RNA_snn_res.0.5', 'seurat_clusters', 'RNA_snn_res.0.1', 'doublet', 'RNA_snn_res.1', 'Cell_type', 'Cell_subtype', 'chemo', 'Therapy', 'Patient', 'Tissue'

# %%
adata_che2021_liver
# Out:
# AnnData object with n_obs × n_vars = 54219 × 33694
#     obs: 'Patient', 'Tissue', 'Therapy', 'Cell_type', 'Cell_subtype', 'Sample'
#     var: 'gene_ids', 'feature_types'

# %%
adata_multiome_raw_liver.obs.Cell_type.value_counts()
# Out:
# Myeloid        1936
# T-NK-ILC       1604
# Stromal         675
# Endothelial     494
# Hepatocyte      474
# B               162
# Name: Cell_type, dtype: int64

# %%
adata_wu2022_liver.obs.Cell_type.value_counts()
# Out:
# CD8        17168
# CD4        13873
# Myeloid     6523
# MAIT        4845
# NK          4626
# NEU         3319
# Treg        2779
# B           1346
# Plasma       766
# Name: Cell_type, dtype: int64

# %%
adata_che2021_liver.obs.Cell_type.value_counts()
# Out:
# T/NK/ILC       39186
# Myeloid         8285
# Plasma           826
# B                788
# Stromal          432
# pDC              216
# cDC1/migDC       178
# Mast              91
# Endothelial       89
# Name: Cell_type, dtype: int64

# %% [markdown]
# ### save data to file

# %%
DIR2SAVE = Path("/data/BCI-CRC/nasrine/data/CRC/Metastatic_CRC_LM_dataset/raw/")
DIR2SAVE.mkdir(parents=True, exist_ok=True)

# %%
# our multiome
adata_multiome_raw_liver.write(DIR2SAVE.joinpath("CRC_LM_decon_raw.h5ad"))

# che2021
adata_che2021_liver.write(DIR2SAVE.joinpath("Che2021_CRC_LM_raw.h5ad"))

# wu2022
adata_wu2022_liver.write(DIR2SAVE.joinpath("Wu2022_CRC_LM_raw.h5ad"))
